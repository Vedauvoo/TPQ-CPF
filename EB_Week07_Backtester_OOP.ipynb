# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedauvoo/TPQ-CPF/blob/main/EB_Week07_Backtester_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Checking python version Colab is using
# !python --version
# Out:
# Python 3.10.12

# %%
#Checking scikit-learn version that Colab is using
import sklearn
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Scikit-learn version: 1.3.2

# %%
#Updating the verion of scikit-learn to the latest version
#This line MUST be executed to ensure reproducable results
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 54.6 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# Successfully installed scikit-learn-1.5.1

# %%
#Checking to make sure install of scikit-learn was successful & on latest version
#IMPORTANT:  MUST SELECT "RESTART SESSION" from "Runtime" drop down menu to get scikit learn version to update
import sklearn
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Scikit-learn version: 1.5.1

# %%
#Code to update colab to use the latest version of python; not needed at this time
#!sudo update-alternatives --config python3
#!sudo apt-get update -y
#!sudo apt-get install python3.12 python3.12-dev python3.12-distutils libpython3.12-dev
#!sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
#!sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 2
#!sudo update-alternatives --config python3
#!python --version

# %%
import math
import numpy as np
import pandas as pd
from pylab import plt
plt.style.use('seaborn-v0_8')
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
class FinancialData(object):
    def __init__(self, symbol):
        self.symbol = symbol
        self.retrieve_data()

    def retrieve_data(self):
        self.raw = pd.read_csv('http://hilpisch.com/ref_eikon_eod_data.csv',
                                 index_col=0, parse_dates=True)
        #print("Original Length of raw = ",len(self.raw))
        self.data = pd.DataFrame(self.raw[self.symbol])
        #self.data['Returns'] = np.log(self.data / self.data.shift(1))
        self.data.dropna(inplace=True)
        #print("Original Length of data = ",len(self.data))

    def plot_data(self, cols=None):
        if cols is None:
            cols = [self.symbol]
        self.data[cols].plot(figsize=(10, 6), title=self.symbol)

# %%
class BacktestingBase(FinancialData):
    def __init__(self, symbol, amount, ptc):
        super(BacktestingBase, self).__init__(symbol)
        self.amount = amount  # cash balance
        self.initial_amount = amount  # initial cash position
        self.ptc = ptc #proportional transaction cost
        self.position = 0  # initial position is neutral
        self.trades = 0  # total number of individual trades
        self.rt_trades = 0 # number of round-trip trades (buy+sell)
        self.units = 0  # number of units of the instrument traded
        self.buy_price = 0 #Initial buy price for Long Entry
        self.sell_price = 0 #Initial sell price for Short Entry
        self.win_count = 0 #Number of trades that are winners
        self.win_rate = 0 #Number of winning trades ratioed to total # of trades
        self.cum_gain = 0 #Cumulative dollar gains
        #print("PTC = ", self.ptc)

    def get_date_price(self, bar):
        return str(self.test.index[bar])[:10], self.test[self.symbol].iloc[bar]

    def print_current_balance(self, bar):
        date, price = self.get_date_price(bar)
        #print('%s | current cash balance is   %8.2f' % (date, self.amount))

    def place_buy_order(self, bar, position=None):
        #print("In Buy Order Method: Position = ",position)
        date, price = self.get_date_price(bar)
        if self.initial_amount is not None and self.trades == 0:
            self.trades += 1
            #print("Trades = 0 & initial_amount not none. Computing units to buy")
            self.units = math.floor(self.initial_amount / (price * (1 + self.ptc)))
            self.buy_price = price*(1 + self.ptc)
            print(55*'=')
            print("%s | Trade # %d Opening LONG Trade" % (date, self.trades))
            print("%s | Trade # %d Amount = $%8.2f"% (date, self.trades,self.amount))
            print("%s | Trade # %d Buy Price w/o TCs = $%8.2f"% (date, self.trades,price))
            print("%s | Trade # %d Buy Price w/ TCs = $%8.2f"% (date, self.trades,self.buy_price))
            print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
            self.amount -= self.units * (price * (1 + self.ptc))
            self.print_current_balance(bar)
        elif position == 0 and self.trades > 0:
            self.trades += 1
            #print("Position= 0 & # of trades > 0. Computing Units to buy")
            self.units = math.floor(self.amount / (price * (1 + self.ptc)))
            self.buy_price = price*(1 + self.ptc)
            print(55*'=')
            print("%s | Trade # %d Opening LONG Trade" % (date, self.trades))
            print("%s | Trade # %d Amount = $%8.2f"% (date, self.trades,self.amount))
            print("%s | Trade # %d Buy Price w/o TCs = $%8.2f"% (date, self.trades,price))
            print("%s | Trade # %d Buy Price w/ TCs = $%8.2f"% (date, self.trades,self.buy_price))
            print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
            #print("computing amount in buy method")
            #Include proportional transaction cost
            self.amount -= self.units * (price * (1 + self.ptc))
            #print('%s | buying  %d units at price %8.2f' % (date, self.units, price))
            self.print_current_balance(bar)
        elif position == -1:
            self.buy_price = price*(1 + self.ptc)
            self.amount -= self.units * (price * (1 + self.ptc))
            self.trades += 1
            self.win_count += np.where(self.sell_price > price, 1, 0)
            print("%s | Trade # %d Closing SHORT Trade" % (date, self.trades))
            print("%s | Trade # %d Buy Price w/o TCs = $%8.2f"% (date, self.trades,price))
            print("%s | Trade # %d Buy Price w/ TCs = $%8.2f"% (date, self.trades,self.buy_price))
            print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
            print("%s | Trade # %d Amount = %8.2f" % (date, self.trades,self.amount))
            print('%s | Trade # %d Gain/Loss %8.2f%%' % (date, self.trades, ((self.sell_price-(self.buy_price))/self.sell_price)*100))
            print('%s | Trade # %d Dollar Gain/Loss $%8.2f' % (date, self.trades, self.units*(self.sell_price-self.buy_price)))
            self.cum_gain += self.units*(self.sell_price-self.buy_price)
            print('%s | Trade # %d Cummulative Gain/Loss $%8.2f' % (date, self.trades,self.cum_gain))

    def place_sell_order(self, bar, position=None):
        date, price = self.get_date_price(bar)
        #print("In Sell Order Method: Position = ",position)
        if self.initial_amount is not None and self.trades == 0:
            self.trades += 1
            #print("Trades = 0 & initial_amount not none. Computing units to sell")
            self.units = math.floor(self.initial_amount / (price * (1 + self.ptc)))
            self.sell_price = price*(1 - self.ptc)
            print(55*'=')
            print("%s | Trade # %d Opening SHORT Trade" % (date, self.trades))
            print("%s | Trade # %d Amount = $%8.2f"% (date, self.trades,self.amount))
            print("%s | Trade # %d Sell Price w/o TCs = $%8.2f"% (date, self.trades,price))
            print("%s | Trade # %d Sell Price w/ TCs = $%8.2f"% (date, self.trades,self.sell_price))
            print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
            self.amount += self.units * (price * (1 - self.ptc))
            self.print_current_balance(bar)
        elif position == 0 and self.trades > 0:
            self.trades += 1
            #print("Position=0 & # of trades > 0. Computing Units to sell")
            self.units = math.floor(self.amount / (price * (1 + self.ptc)))
            self.sell_price = price*(1 - self.ptc)
            print(55*'=')
            print("%s | Trade # %d Opening SHORT Trade" % (date, self.trades))
            print("%s | Trade # %d Amount = $%8.2f"% (date, self.trades,self.amount))
            print("%s | Trade # %d Sell Price w/o TCs = $%8.2f"% (date, self.trades,price))
            print("%s | Trade # %d Sell Price w/ TCs = $%8.2f"% (date, self.trades,self.sell_price))
            print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
            self.amount += self.units * (price * (1 - self.ptc))
            #print('%s | selling %d units at price %8.2f' % (date, self.units, price))
            self.print_current_balance(bar)
        elif position == 1:
            self.sell_price = price*(1 - self.ptc)
            self.amount += self.units * (price * (1 - self.ptc))
            self.trades += 1
            self.win_count += np.where(self.buy_price < price, 1, 0)
            print("%s | Trade # %d Closing LONG Trade" % (date, self.trades))
            print("%s | Trade # %d Sell Price w/o TCs = $%8.2f"% (date, self.trades,price))
            print("%s | Trade # %d Sell Price w/ TCs = $%8.2f"% (date, self.trades,self.sell_price))
            print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
            print("%s | Trade # %d Amount = %8.2f" % (date, self.trades,self.amount))
            print('%s | Trade # %d Gain/Loss %8.2f%%' % (date, self.trades, ((self.sell_price-self.buy_price)/self.buy_price)*100))
            print('%s | Trade # %d Dollar Gain/Loss $%8.2f' % (date, self.trades, self.units*(self.sell_price-self.buy_price)))
            self.cum_gain += self.units*(self.sell_price-self.buy_price)
            print('%s | Trade # %d Cummulative Gain/Loss $%8.2f' % (date, self.trades,self.cum_gain))

    def close_out(self, bar, position):
        date, price = self.get_date_price(bar)
        #print(50 * '=')
        if position == 1:
          #self.sell_price = price*(1 - self.ptc)
          #self.amount += self.units * (price * (1 - self.ptc))
          self.amount += self.units * self.buy_price
          #self.trades += 1
          self.trades -= 1
          #self.win_count += np.where(self.buy_price < price, 1, 0)
          print("%s | Trade # %d Not enough data to complete trade. Excluding This LONG Trade From Final Results" % (date, self.trades))
          #print("%s | Trade # %d Sell Price w/o TCs = $%8.2f"% (date, self.trades,price))
          #print("%s | Trade # %d Sell Price w/ TCs = $%8.2f"% (date, self.trades,self.sell_price))
          print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
          #print('%s | Trade # %d Gain/Loss %8.2f%%' % (date, self.trades, ((self.sell_price-self.buy_price)/self.buy_price)*100))
          #print('%s | Trade # %d Dollar Gain/Loss $%8.2f' % (date, self.trades, self.units*(self.sell_price-self.buy_price)))
          #self.cum_gain += self.units*(self.sell_price-self.buy_price)
          print('%s | Trade # %d Cummulative Gain/Loss $%8.2f' % (date, self.trades,self.cum_gain))
        elif position == -1:
          #self.buy_price = price*(1 + self.ptc)
          #self.amount -= self.units * (price * (1 + self.ptc))
          self.amount -= self.units * self.sell_price
          #self.trades += 1
          self.trades -= 1
          #self.win_count += np.where(self.sell_price > price, 1, 0)
          print("%s | Trade # %d Not enought data to complete trade. Excluding This SHORT Trade From Final Results" % (date, self.trades))
          #print("%s | Trade # %d Buy Price w/o TCs = $%8.2f"% (date, self.trades,price))
          #print("%s | Trade # %d Buy Price w/ TCs = $%8.2f"% (date, self.trades,self.buy_price))
          print("%s | Trade # %d # of Units = %8.2f"% (date, self.trades,self.units))
          #print('%s | Trade # %d Gain/Loss %8.2f%%' % (date, self.trades, ((self.sell_price-(self.buy_price))/self.sell_price)*100))
          #print('%s | Trade # %d Dollar Gain/Loss $%8.2f' % (date, self.trades, self.units*(self.sell_price-self.buy_price)))
          #self.cum_gain += self.units*(self.sell_price-self.buy_price)
          print('%s | Trade # %d Cummulative Gain/Loss $%8.2f' % (date, self.trades,self.cum_gain))

        print("%s | Trade # %d STARTING AMOUNT = %8.2f" % (date, self.trades,self.initial_amount))
        print("%s | Trade # %d FINAL AMOUNT = %8.2f" % (date, self.trades,self.amount))
        perf = (self.amount / self.initial_amount - 1) * 100
        print('%s | NET RETURN OF STRATEGY = %7.2f%%' % (date, perf))
        print("Number of Indivdual Trades: ",self.trades)
        self.rt_trades=(self.trades/2)
        print("Number of Round Trip Trades: ",self.rt_trades)
        print('Number of Winning Trades:',self.win_count)
        if self.trades >= 1:
          self.win_rate = (self.win_count/(self.rt_trades))*100
        else:
          self.win_rate = 0
        print('Win Rate: %7.2f%%' % self.win_rate)
        #print(110 * '=')
        return perf, self.rt_trades, self.win_rate

# %%
class BacktestingModelsStrategy(BacktestingBase):
    #def __init__(self, symbol, amount, algo_type, SMA1, SMA2, EMA1, EMA2, Vol1, Vol2, L1, L2, MaxD, MSL, Win):
    def __init__(self, symbol, amount, ptc, algo_type, Win):
        super(BacktestingModelsStrategy, self).__init__(symbol, amount, ptc)
        self.symbol = symbol
        self.algo_type = algo_type
        self.lags = 5
        self.L1 = 1.5
        #self.L1 = L1
        self.L2 = 8
        #self.L2 = L2
        self.SMA1 = 35
        #self.SMA1 = SMA1
        self.SMA2 = 196
        #self.SMA2 = SMA2
        self.EMA1 = 50
        #self.EMA1 = EMA1
        self.EMA2 = 180
        #self.EMA2 = EMA2
        self.Vol1 = 90
        #self.Vol1 = Vol1
        self.Vol2 = 190
        #self.Vol2 = Vol2
        self.Win = Win
        #self.MaxD = MaxD
        #self.MSL = MSL
        self.cols = []
        self.df = self.data.copy()
        self.prepare_statistics()
        self.results = pd.DataFrame()

    def prepare_statistics(self):
        #self.df = self.df.dropna(inplace=True)
        self.df['returns'] = np.log(self.df[self.symbol] / self.df[self.symbol].shift(1))

        self.lr_sigma = self.df['returns'].std()
        self.df['d_cat'] = np.digitize(self.df['returns'], bins=[-1*self.L2*self.lr_sigma, -1*self.L1*self.lr_sigma, self.L1*self.lr_sigma, self.L2*self.lr_sigma])

        self.df['SMA1'] = self.df[self.symbol].rolling(self.SMA1).mean()
        self.df['SMA2'] = self.df[self.symbol].rolling(self.SMA2).mean()
        self.df['SMA_Diff'] = self.df['SMA1']-self.df['SMA2']

        self.df['EMA1'] = self.df[self.symbol].ewm(span=self.EMA1, adjust=False).mean()
        self.df['EMA2'] = self.df[self.symbol].ewm(span=self.EMA2, adjust=False).mean()
        self.df['EMA_Diff'] = self.df['EMA1']-self.df['EMA2']

        self.df['Vol1'] = self.df['returns'].rolling(self.Vol1).std()
        self.df['Vol2'] = self.df['returns'].rolling(self.Vol2).std()
        #self.df.dropna(inplace=True)
        self.df['d'] = np.where(self.df['returns'] > 0, 1, 0)

        self.features = ['returns', 'd', 'd_cat', 'SMA1', 'SMA2', 'SMA_Diff','EMA1', 'EMA2', 'EMA_Diff', 'Vol1', 'Vol2']

        for f in self.features:
            for lag in range(1, self.lags + 1):
                col = f'{f}_lag_{lag}'
                self.df[col] = self.df[f].shift(lag)
                self.cols.append(col)
        self.df.dropna(inplace=True)
        #print("Return df and cols")
        #print("Length of df= ",len(self.df))
        return self.df, self.cols

    def normalize_data(self, data):
        split = int(len(self.data) * 0.7)
        #print("split = ",split)
        self.train = self.data.iloc[:split].copy()
        self.test = self.data.iloc[split:].copy()
        #print("Training Length = ",len(self.train))
        #print("Testing Length = ",len(self.test))
        #print("values in self.train = ",self.train)
        mu, std = self.train.mean(), self.train.std()
        self.train_ = (self.train - mu) / std
        self.test_ = (self.test-mu)/std
        #print("Normalized Training Length = ",len(self.train_))
        #print("Normalized_Testing Length = ",len(self.test_))
        return self.train_,self.test_,self.train,self.test
        #return self.train,self.test

    def run_strategy(self, Parms=None):
        self.position = 0
        self.final_bar = 0
        self.units = 0
        self.trades = 0
        self.count_scenarios = 0
        self.amount = self.initial_amount
        if Parms is not None:
            #self.SMA1 = Parms[0]
            #print("SMA1 = ", self.SMA1)
            #self.SMA2 = Parms[1]
            #print("SMA2 = ", self.SMA2)
            #self.EMA1 = Parms[2]
            #print("EMA1 = ", self.EMA1)
            #self.EMA2 = Parms[3]
            #print("EMA2 = ", self.EMA2)
            #self.Vol1 = Parms[4]
            #print("Vol1 = ", self.Vol1)
            #self.Vol2 = Parms[5]
            #print("Vol2 = ", self.Vol2)
            #self.L1 = Parms[6]
            #print("L1 = ", self.L1)
            #self.L2 = Parms[7]
            #print("L2 = ", self.L2)
            #self.MaxD = Parms[8]
            #self.MaxD = Parms[0]
            #print("MaxD = ", self.MaxD)
            #self.MSL = Parms[9]
            #self.MSL = Parms[1]
            #print("MSL = ", self.MSL)
            #self.Win = Parms[10]
            #self.Win = Parms[0]
            print("Win = ", self.Win)
            #print('Calling method prepare_statistics')
            self.data, self.cols = self.prepare_statistics()

        #print('Splitting & Normalizing Data')
        self.train_,self.test_,self.train,self.test = self.normalize_data(self.data)

        print(110 * '=')
        print(f'*** START BACKTESTING ***')
        print(f'SYM={self.symbol} | Lags={self.lags} | SMA1={self.SMA1} | SMA2={self.SMA2} | L1={self.L1}| L2={self.L2} | EMA1={self.EMA1} | EMA2={self.EMA2} | Vol1={self.Vol1}| Vol2={self.Vol2} | Win={self.Win}')
        print(110 * '=')

        if self.algo_type == "DTC":
          print('Creating DTC Model')
          #self.model = tree.DecisionTreeClassifier(max_depth=3,min_samples_leaf=5)
          #self.model = tree.DecisionTreeClassifier(max_depth=2,min_samples_leaf=25)
          self.model = tree.DecisionTreeClassifier(max_depth=1,min_samples_leaf=20)
          #self.model = tree.DecisionTreeClassifier(max_depth=self.MaxD,min_samples_leaf=self.MSL)
        elif self.algo_type == "Gaussian":
          print('Creating GaussianNB Model')
          self.model = GaussianNB()
        elif self.algo_type == "LR":
          print('Creating LogisticRegression Model')
          #self.model = LogisticRegression(C=0.001, solver='saga', multi_class='auto', max_iter=3100)
          #self.model = LogisticRegression(C=0.1, solver='lbfgs', multi_class='auto', max_iter=3100)
          self.model = LogisticRegression(C=0.00001, solver='saga', max_iter=3100)
        elif self.algo_type == "SVC":
          print('Creating SVC Model')
          self.model = SVC(C=0.1, kernel='rbf', probability=True)
        elif self.algo_type == "MLPC":
          print('Creating MLPClassifier Model')
          self.model = MLPClassifier(hidden_layer_sizes=[48], max_iter=2000, random_state=100,shuffle=False)
        else:
          print('Please enter a valid model type: DTC, Gaussian, LR, SVC, MLPC')

        #n is the sliding window width/size
        n = self.Win
        start = n

        #for bar in range(len(self.test)):
        for bar in range(start, len(self.test)):
              #print(f'Fitting {self.algo_type} Model')
              self.model.fit(self.train_[self.cols].iloc[bar-n:bar], self.train['d'].iloc[bar-n:bar])
              #print('Perform Prediction on Normalized Training Data (train_)')
              self.train.loc[self.train.index[bar], 'p'] = self.model.predict(self.train_[self.cols].iloc[bar-n:bar])[0]
              #print('Perform Prediction on Normalized Test Data (test_)')
              self.test.loc[self.test.index[bar],'p'] = self.model.predict(self.test_[self.cols].iloc[bar-n:bar])[0]
              if self.position == 0 or self.position ==-1:
                  if self.test['p'].iloc[bar] > 0:
                      if self.position == -1:
                        self.place_buy_order(bar, self.position)
                        self.position = 0
                      self.place_buy_order(bar, self.position)
                      self.position = 1
                      #print(55*'=')
              if self.position == 0 or self.position == 1:
                  if self.test['p'].iloc[bar] <= 0:
                      if self.position == 1:
                        self.place_sell_order(bar, self.position)
                        self.position = 0
                      self.place_sell_order(bar, self.position)
                      self.position = -1
                      #print(55*'=')
              self.final_bar = bar
        perf, trades, win_rate = self.close_out(self.final_bar, self.position)
        self.train.dropna(inplace=True)
        accuracy_is = accuracy_score(self.train['d'], self.train['p'])
        print("IN SAMPLE Model Prediction Accuracy train['d'] vs train['p'] (%) = ", accuracy_is*100)
        p_nans_test = self.test['p'].isnull().sum()
        accuracy_oos = accuracy_score(self.test['d'].iloc[p_nans_test:], self.test['p'].iloc[p_nans_test:])
        print("OUT OF SAMPLE Model Prediction Accuracy test['d'] vs test['p'] (%) = ", accuracy_oos*100)
        #print("Value of final_bar = ",self.final_bar)
        self.results[['Perf(%)','Trades','WinRate','AIS', 'AOOS','Lags','SMA1','SMA2','L1','L2','EMA1','EMA2','Vol1','Vol2','Win']] = [[perf, trades, win_rate, accuracy_is, accuracy_oos, self.lags, self.SMA1, self.SMA2, self.L1, self.L2, self.EMA1, self.EMA2, self.Vol1, self.Vol2, self.Win]]
        print(110 * '=')
        return self.results

# %%
def DTC_OOS():
  out_of_sample_results = pd.DataFrame()
  #Set proportional transaction cost at 0.5%
  ptc = 0.005
  #Sliding window size set to 385 days
  Win = 385
  DTC = BacktestingModelsStrategy('AAPL.O', 10000, ptc, 'DTC', Win)
  out_of_sample_results = DTC.run_strategy(Win)

# %%
# %%time
DTC_OOS_Results = DTC_OOS()
# Out:
# Win =  385
# ==============================================================================================================
# *** START BACKTESTING ***
# SYM=AAPL.O | Lags=5 | SMA1=35 | SMA2=196 | L1=1.5| L2=8 | EMA1=50 | EMA2=180 | Vol1=90| Vol2=190 | Win=385
# ==============================================================================================================
# Creating DTC Model
# =======================================================
# 2018-08-27 | Trade # 1 Opening LONG Trade
# 2018-08-27 | Trade # 1 Amount = $10000.00
# 2018-08-27 | Trade # 1 Buy Price w/o TCs = $  217.94
# 2018-08-27 | Trade # 1 Buy Price w/ TCs = $  219.03
# 2018-08-27 | Trade # 1 # of Units =    45.00
# 2018-09-26 | Trade # 2 Closing LONG Trade
# 2018-09-26 | Trade # 2 Sell Price w/o TCs = $  220.42
# 2018-09-26 | Trade # 2 Sell Price w/ TCs = $  219.32
# 2018-09-26 | Trade # 2 # of Units =    45.00
# 2018-09-26 | Trade # 2 Amount = 10012.97
# 2018-09-26 | Trade # 2 Gain/Loss     0.13%
# 2018-09-26 | Trade # 2 Dollar Gain/Loss $   12.97
# 2018-09-26 | Trade # 2 Cummulative Gain/Loss $   12.97
# =======================================================
# 2018-09-26 | Trade # 3 Opening SHORT Trade
# 2018-09-26 | Trade # 3 Amount = $10012.97
# 2018-09-26 | Trade # 3 Sell Price w/o TCs = $  220.42
# 2018-09-26 | Trade # 3 Sell Price w/ TCs = $  219.32
# 2018-09-26 | Trade # 3 # of Units =    45.00
# 2018-10-15 | Trade # 4 Closing SHORT Trade
# 2018-10-15 | Trade # 4 Buy Price w/o TCs = $  217.36
# 2018-10-15 | Trade # 4 Buy Price w/ TCs = $  218.45
# 2018-10-15 | Trade # 4 # of Units =    45.00
# 2018-10-15 | Trade # 4 Amount = 10052.17
# 2018-10-15 | Trade # 4 Gain/Loss     0.40%
# 2018-10-15 | Trade # 4 Dollar Gain/Loss $   39.20
# 2018-10-15 | Trade # 4 Cummulative Gain/Loss $   52.17
# =======================================================
# 2018-10-15 | Trade # 5 Opening LONG Trade
# 2018-10-15 | Trade # 5 Amount = $10052.17
# 2018-10-15 | Trade # 5 Buy Price w/o TCs = $  217.36
# 2018-10-15 | Trade # 5 Buy Price w/ TCs = $  218.45
# 2018-10-15 | Trade # 5 # of Units =    46.00
# 2018-10-16 | Trade # 6 Closing LONG Trade
# 2018-10-16 | Trade # 6 Sell Price w/o TCs = $  222.15
# 2018-10-16 | Trade # 6 Sell Price w/ TCs = $  221.04
# 2018-10-16 | Trade # 6 # of Units =    46.00
# 2018-10-16 | Trade # 6 Amount = 10171.42
# 2018-10-16 | Trade # 6 Gain/Loss     1.19%
# 2018-10-16 | Trade # 6 Dollar Gain/Loss $  119.25
# 2018-10-16 | Trade # 6 Cummulative Gain/Loss $  171.42
# =======================================================
# 2018-10-16 | Trade # 7 Opening SHORT Trade
# 2018-10-16 | Trade # 7 Amount = $10171.42
# 2018-10-16 | Trade # 7 Sell Price w/o TCs = $  222.15
# 2018-10-16 | Trade # 7 Sell Price w/ TCs = $  221.04
# 2018-10-16 | Trade # 7 # of Units =    45.00
# 2018-10-29 | Trade # 8 Closing SHORT Trade
# 2018-10-29 | Trade # 8 Buy Price w/o TCs = $  212.24
# 2018-10-29 | Trade # 8 Buy Price w/ TCs = $  213.30
# 2018-10-29 | Trade # 8 # of Units =    45.00
# 2018-10-29 | Trade # 8 Amount = 10519.63
# 2018-10-29 | Trade # 8 Gain/Loss     3.50%
# 2018-10-29 | Trade # 8 Dollar Gain/Loss $  348.21
# 2018-10-29 | Trade # 8 Cummulative Gain/Loss $  519.63
# =======================================================
# 2018-10-29 | Trade # 9 Opening LONG Trade
# 2018-10-29 | Trade # 9 Amount = $10519.63
# 2018-10-29 | Trade # 9 Buy Price w/o TCs = $  212.24
# 2018-10-29 | Trade # 9 Buy Price w/ TCs = $  213.30
# 2018-10-29 | Trade # 9 # of Units =    49.00
# 2018-10-30 | Trade # 10 Closing LONG Trade
# 2018-10-30 | Trade # 10 Sell Price w/o TCs = $  213.30
# 2018-10-30 | Trade # 10 Sell Price w/ TCs = $  212.23
# 2018-10-30 | Trade # 10 # of Units =    49.00
# 2018-10-30 | Trade # 10 Amount = 10467.32
# 2018-10-30 | Trade # 10 Gain/Loss    -0.50%
# 2018-10-30 | Trade # 10 Dollar Gain/Loss $  -52.32
# 2018-10-30 | Trade # 10 Cummulative Gain/Loss $  467.32
# =======================================================
# 2018-10-30 | Trade # 11 Opening SHORT Trade
# 2018-10-30 | Trade # 11 Amount = $10467.32
# 2018-10-30 | Trade # 11 Sell Price w/o TCs = $  213.30
# 2018-10-30 | Trade # 11 Sell Price w/ TCs = $  212.23
# 2018-10-30 | Trade # 11 # of Units =    48.00
# 2019-01-30 | Trade # 12 Closing SHORT Trade
# 2019-01-30 | Trade # 12 Buy Price w/o TCs = $  165.25
# 2019-01-30 | Trade # 12 Buy Price w/ TCs = $  166.08
# 2019-01-30 | Trade # 12 # of Units =    48.00
# 2019-01-30 | Trade # 12 Amount = 12682.86
# 2019-01-30 | Trade # 12 Gain/Loss    21.75%
# 2019-01-30 | Trade # 12 Dollar Gain/Loss $ 2215.55
# 2019-01-30 | Trade # 12 Cummulative Gain/Loss $ 2682.86
# =======================================================
# 2019-01-30 | Trade # 13 Opening LONG Trade
# 2019-01-30 | Trade # 13 Amount = $12682.86
# 2019-01-30 | Trade # 13 Buy Price w/o TCs = $  165.25
# 2019-01-30 | Trade # 13 Buy Price w/ TCs = $  166.08
# 2019-01-30 | Trade # 13 # of Units =    76.00
# 2019-02-07 | Trade # 14 Closing LONG Trade
# 2019-02-07 | Trade # 14 Sell Price w/o TCs = $  170.94
# 2019-02-07 | Trade # 14 Sell Price w/ TCs = $  170.09
# 2019-02-07 | Trade # 14 # of Units =    76.00
# 2019-02-07 | Trade # 14 Amount = 12987.55
# 2019-02-07 | Trade # 14 Gain/Loss     2.41%
# 2019-02-07 | Trade # 14 Dollar Gain/Loss $  304.69
# 2019-02-07 | Trade # 14 Cummulative Gain/Loss $ 2987.55
# =======================================================
# 2019-02-07 | Trade # 15 Opening SHORT Trade
# 2019-02-07 | Trade # 15 Amount = $12987.55
# 2019-02-07 | Trade # 15 Sell Price w/o TCs = $  170.94
# 2019-02-07 | Trade # 15 Sell Price w/ TCs = $  170.09
# 2019-02-07 | Trade # 15 # of Units =    75.00
# 2019-03-07 | Trade # 16 Closing SHORT Trade
# 2019-03-07 | Trade # 16 Buy Price w/o TCs = $  172.50
# 2019-03-07 | Trade # 16 Buy Price w/ TCs = $  173.36
# 2019-03-07 | Trade # 16 # of Units =    75.00
# 2019-03-07 | Trade # 16 Amount = 12741.76
# 2019-03-07 | Trade # 16 Gain/Loss    -1.93%
# 2019-03-07 | Trade # 16 Dollar Gain/Loss $ -245.79
# 2019-03-07 | Trade # 16 Cummulative Gain/Loss $ 2741.76
# =======================================================
# 2019-03-07 | Trade # 17 Opening LONG Trade
# 2019-03-07 | Trade # 17 Amount = $12741.76
# 2019-03-07 | Trade # 17 Buy Price w/o TCs = $  172.50
# 2019-03-07 | Trade # 17 Buy Price w/ TCs = $  173.36
# 2019-03-07 | Trade # 17 # of Units =    73.00
# 2019-04-12 | Trade # 18 Closing LONG Trade
# 2019-04-12 | Trade # 18 Sell Price w/o TCs = $  198.87
# 2019-04-12 | Trade # 18 Sell Price w/ TCs = $  197.88
# 2019-04-12 | Trade # 18 # of Units =    73.00
# 2019-04-12 | Trade # 18 Amount = 14531.22
# 2019-04-12 | Trade # 18 Gain/Loss    14.14%
# 2019-04-12 | Trade # 18 Dollar Gain/Loss $ 1789.46
# 2019-04-12 | Trade # 18 Cummulative Gain/Loss $ 4531.22
# =======================================================
# 2019-04-12 | Trade # 19 Opening SHORT Trade
# 2019-04-12 | Trade # 19 Amount = $14531.22
# 2019-04-12 | Trade # 19 Sell Price w/o TCs = $  198.87
# 2019-04-12 | Trade # 19 Sell Price w/ TCs = $  197.88
# 2019-04-12 | Trade # 19 # of Units =    72.00
# 2019-04-16 | Trade # 20 Closing SHORT Trade
# 2019-04-16 | Trade # 20 Buy Price w/o TCs = $  199.25
# 2019-04-16 | Trade # 20 Buy Price w/ TCs = $  200.25
# 2019-04-16 | Trade # 20 # of Units =    72.00
# 2019-04-16 | Trade # 20 Amount = 14360.54
# 2019-04-16 | Trade # 20 Gain/Loss    -1.20%
# 2019-04-16 | Trade # 20 Dollar Gain/Loss $ -170.68
# 2019-04-16 | Trade # 20 Cummulative Gain/Loss $ 4360.54
# =======================================================
# 2019-04-16 | Trade # 21 Opening LONG Trade
# 2019-04-16 | Trade # 21 Amount = $14360.54
# 2019-04-16 | Trade # 21 Buy Price w/o TCs = $  199.25
# 2019-04-16 | Trade # 21 Buy Price w/ TCs = $  200.25
# 2019-04-16 | Trade # 21 # of Units =    71.00
# 2019-04-23 | Trade # 22 Closing LONG Trade
# 2019-04-23 | Trade # 22 Sell Price w/o TCs = $  207.48
# 2019-04-23 | Trade # 22 Sell Price w/ TCs = $  206.44
# 2019-04-23 | Trade # 22 # of Units =    71.00
# 2019-04-23 | Trade # 22 Amount = 14800.48
# 2019-04-23 | Trade # 22 Gain/Loss     3.09%
# 2019-04-23 | Trade # 22 Dollar Gain/Loss $  439.94
# 2019-04-23 | Trade # 22 Cummulative Gain/Loss $ 4800.48
# =======================================================
# 2019-04-23 | Trade # 23 Opening SHORT Trade
# 2019-04-23 | Trade # 23 Amount = $14800.48
# 2019-04-23 | Trade # 23 Sell Price w/o TCs = $  207.48
# 2019-04-23 | Trade # 23 Sell Price w/ TCs = $  206.44
# 2019-04-23 | Trade # 23 # of Units =    70.00
# 2019-04-25 | Trade # 24 Closing SHORT Trade
# 2019-04-25 | Trade # 24 Buy Price w/o TCs = $  205.28
# 2019-04-25 | Trade # 24 Buy Price w/ TCs = $  206.31
# 2019-04-25 | Trade # 24 # of Units =    70.00
# 2019-04-25 | Trade # 24 Amount = 14810.01
# 2019-04-25 | Trade # 24 Gain/Loss     0.07%
# 2019-04-25 | Trade # 24 Dollar Gain/Loss $    9.53
# 2019-04-25 | Trade # 24 Cummulative Gain/Loss $ 4810.01
# =======================================================
# 2019-04-25 | Trade # 25 Opening LONG Trade
# 2019-04-25 | Trade # 25 Amount = $14810.01
# 2019-04-25 | Trade # 25 Buy Price w/o TCs = $  205.28
# 2019-04-25 | Trade # 25 Buy Price w/ TCs = $  206.31
# 2019-04-25 | Trade # 25 # of Units =    71.00
# 2019-05-09 | Trade # 26 Closing LONG Trade
# 2019-05-09 | Trade # 26 Sell Price w/o TCs = $  200.72
# 2019-05-09 | Trade # 26 Sell Price w/ TCs = $  199.72
# 2019-05-09 | Trade # 26 # of Units =    71.00
# 2019-05-09 | Trade # 26 Amount = 14342.12
# 2019-05-09 | Trade # 26 Gain/Loss    -3.19%
# 2019-05-09 | Trade # 26 Dollar Gain/Loss $ -467.89
# 2019-05-09 | Trade # 26 Cummulative Gain/Loss $ 4342.12
# =======================================================
# 2019-05-09 | Trade # 27 Opening SHORT Trade
# 2019-05-09 | Trade # 27 Amount = $14342.12
# 2019-05-09 | Trade # 27 Sell Price w/o TCs = $  200.72
# 2019-05-09 | Trade # 27 Sell Price w/ TCs = $  199.72
# 2019-05-09 | Trade # 27 # of Units =    71.00
# 2019-06-03 | Trade # 28 Closing SHORT Trade
# 2019-06-03 | Trade # 28 Buy Price w/o TCs = $  173.30
# 2019-06-03 | Trade # 28 Buy Price w/ TCs = $  174.17
# 2019-06-03 | Trade # 28 # of Units =    71.00
# 2019-06-03 | Trade # 28 Amount = 16156.17
# 2019-06-03 | Trade # 28 Gain/Loss    12.79%
# 2019-06-03 | Trade # 28 Dollar Gain/Loss $ 1814.04
# 2019-06-03 | Trade # 28 Cummulative Gain/Loss $ 6156.17
# =======================================================
# 2019-06-03 | Trade # 29 Opening LONG Trade
# 2019-06-03 | Trade # 29 Amount = $16156.17
# 2019-06-03 | Trade # 29 Buy Price w/o TCs = $  173.30
# 2019-06-03 | Trade # 29 Buy Price w/ TCs = $  174.17
# 2019-06-03 | Trade # 29 # of Units =    92.00
# 2019-06-04 | Trade # 30 Closing LONG Trade
# 2019-06-04 | Trade # 30 Sell Price w/o TCs = $  179.64
# 2019-06-04 | Trade # 30 Sell Price w/ TCs = $  178.74
# 2019-06-04 | Trade # 30 # of Units =    92.00
# 2019-06-04 | Trade # 30 Amount = 16577.09
# 2019-06-04 | Trade # 30 Gain/Loss     2.63%
# 2019-06-04 | Trade # 30 Dollar Gain/Loss $  420.93
# 2019-06-04 | Trade # 30 Cummulative Gain/Loss $ 6577.09
# =======================================================
# 2019-06-04 | Trade # 31 Opening SHORT Trade
# 2019-06-04 | Trade # 31 Amount = $16577.09
# 2019-06-04 | Trade # 31 Sell Price w/o TCs = $  179.64
# 2019-06-04 | Trade # 31 Sell Price w/ TCs = $  178.74
# 2019-06-04 | Trade # 31 # of Units =    91.00
# 2019-06-05 | Trade # 32 Closing SHORT Trade
# 2019-06-05 | Trade # 32 Buy Price w/o TCs = $  182.54
# 2019-06-05 | Trade # 32 Buy Price w/ TCs = $  183.45
# 2019-06-05 | Trade # 32 # of Units =    91.00
# 2019-06-05 | Trade # 32 Amount = 16148.40
# 2019-06-05 | Trade # 32 Gain/Loss    -2.64%
# 2019-06-05 | Trade # 32 Dollar Gain/Loss $ -428.69
# 2019-06-05 | Trade # 32 Cummulative Gain/Loss $ 6148.40
# =======================================================
# 2019-06-05 | Trade # 33 Opening LONG Trade
# 2019-06-05 | Trade # 33 Amount = $16148.40
# 2019-06-05 | Trade # 33 Buy Price w/o TCs = $  182.54
# 2019-06-05 | Trade # 33 Buy Price w/ TCs = $  183.45
# 2019-06-05 | Trade # 33 # of Units =    88.00
# 2019-06-07 | Trade # 34 Closing LONG Trade
# 2019-06-07 | Trade # 34 Sell Price w/o TCs = $  190.15
# 2019-06-07 | Trade # 34 Sell Price w/ TCs = $  189.20
# 2019-06-07 | Trade # 34 # of Units =    88.00
# 2019-06-07 | Trade # 34 Amount = 16654.10
# 2019-06-07 | Trade # 34 Gain/Loss     3.13%
# 2019-06-07 | Trade # 34 Dollar Gain/Loss $  505.70
# 2019-06-07 | Trade # 34 Cummulative Gain/Loss $ 6654.10
# =======================================================
# 2019-06-07 | Trade # 35 Opening SHORT Trade
# 2019-06-07 | Trade # 35 Amount = $16654.10
# 2019-06-07 | Trade # 35 Sell Price w/o TCs = $  190.15
# 2019-06-07 | Trade # 35 Sell Price w/ TCs = $  189.20
# 2019-06-07 | Trade # 35 # of Units =    87.00
# 2019-06-11 | Trade # 36 Closing SHORT Trade
# 2019-06-11 | Trade # 36 Buy Price w/o TCs = $  194.81
# 2019-06-11 | Trade # 36 Buy Price w/ TCs = $  195.78
# 2019-06-11 | Trade # 36 # of Units =    87.00
# 2019-06-11 | Trade # 36 Amount = 16081.22
# 2019-06-11 | Trade # 36 Gain/Loss    -3.48%
# 2019-06-11 | Trade # 36 Dollar Gain/Loss $ -572.88
# 2019-06-11 | Trade # 36 Cummulative Gain/Loss $ 6081.22
# =======================================================
# 2019-06-11 | Trade # 37 Opening LONG Trade
# 2019-06-11 | Trade # 37 Amount = $16081.22
# 2019-06-11 | Trade # 37 Buy Price w/o TCs = $  194.81
# 2019-06-11 | Trade # 37 Buy Price w/ TCs = $  195.78
# 2019-06-11 | Trade # 37 # of Units =    82.00
# 2019-06-13 | Trade # 38 Closing LONG Trade
# 2019-06-13 | Trade # 38 Sell Price w/o TCs = $  194.15
# 2019-06-13 | Trade # 38 Sell Price w/ TCs = $  193.18
# 2019-06-13 | Trade # 38 # of Units =    82.00
# 2019-06-13 | Trade # 38 Amount = 15867.63
# 2019-06-13 | Trade # 38 Gain/Loss    -1.33%
# 2019-06-13 | Trade # 38 Dollar Gain/Loss $ -213.59
# 2019-06-13 | Trade # 38 Cummulative Gain/Loss $ 5867.63
# =======================================================
# 2019-06-13 | Trade # 39 Opening SHORT Trade
# 2019-06-13 | Trade # 39 Amount = $15867.63
# 2019-06-13 | Trade # 39 Sell Price w/o TCs = $  194.15
# 2019-06-13 | Trade # 39 Sell Price w/ TCs = $  193.18
# 2019-06-13 | Trade # 39 # of Units =    81.00
# 2019-06-25 | Trade # 40 Closing SHORT Trade
# 2019-06-25 | Trade # 40 Buy Price w/o TCs = $  195.57
# 2019-06-25 | Trade # 40 Buy Price w/ TCs = $  196.55
# 2019-06-25 | Trade # 40 # of Units =    81.00
# 2019-06-25 | Trade # 40 Amount = 15594.77
# 2019-06-25 | Trade # 40 Gain/Loss    -1.74%
# 2019-06-25 | Trade # 40 Dollar Gain/Loss $ -272.86
# 2019-06-25 | Trade # 40 Cummulative Gain/Loss $ 5594.77
# =======================================================
# 2019-06-25 | Trade # 41 Opening LONG Trade
# 2019-06-25 | Trade # 41 Amount = $15594.77
# 2019-06-25 | Trade # 41 Buy Price w/o TCs = $  195.57
# 2019-06-25 | Trade # 41 Buy Price w/ TCs = $  196.55
# 2019-06-25 | Trade # 41 # of Units =    79.00
# 2019-06-26 | Trade # 42 Closing LONG Trade
# 2019-06-26 | Trade # 42 Sell Price w/o TCs = $  199.80
# 2019-06-26 | Trade # 42 Sell Price w/ TCs = $  198.80
# 2019-06-26 | Trade # 42 # of Units =    79.00
# 2019-06-26 | Trade # 42 Amount = 15772.77
# 2019-06-26 | Trade # 42 Gain/Loss     1.15%
# 2019-06-26 | Trade # 42 Dollar Gain/Loss $  178.00
# 2019-06-26 | Trade # 42 Cummulative Gain/Loss $ 5772.77
# =======================================================
# 2019-06-26 | Trade # 43 Opening SHORT Trade
# 2019-06-26 | Trade # 43 Amount = $15772.77
# 2019-06-26 | Trade # 43 Sell Price w/o TCs = $  199.80
# 2019-06-26 | Trade # 43 Sell Price w/ TCs = $  198.80
# 2019-06-26 | Trade # 43 # of Units =    78.00
# 2019-06-28 | Trade # 44 Closing SHORT Trade
# 2019-06-28 | Trade # 44 Buy Price w/o TCs = $  197.92
# 2019-06-28 | Trade # 44 Buy Price w/ TCs = $  198.91
# 2019-06-28 | Trade # 44 # of Units =    78.00
# 2019-06-28 | Trade # 44 Amount = 15764.30
# 2019-06-28 | Trade # 44 Gain/Loss    -0.05%
# 2019-06-28 | Trade # 44 Dollar Gain/Loss $   -8.47
# 2019-06-28 | Trade # 44 Cummulative Gain/Loss $ 5764.30
# =======================================================
# 2019-06-28 | Trade # 45 Opening LONG Trade
# 2019-06-28 | Trade # 45 Amount = $15764.30
# 2019-06-28 | Trade # 45 Buy Price w/o TCs = $  197.92
# 2019-06-28 | Trade # 45 Buy Price w/ TCs = $  198.91
# 2019-06-28 | Trade # 45 # of Units =    79.00
# 2019-07-01 | Trade # 46 Closing LONG Trade
# 2019-07-01 | Trade # 46 Sell Price w/o TCs = $  201.55
# 2019-07-01 | Trade # 46 Sell Price w/ TCs = $  200.54
# 2019-07-01 | Trade # 46 # of Units =    79.00
# 2019-07-01 | Trade # 46 Amount = 15893.28
# 2019-07-01 | Trade # 46 Gain/Loss     0.82%
# 2019-07-01 | Trade # 46 Dollar Gain/Loss $  128.98
# 2019-07-01 | Trade # 46 Cummulative Gain/Loss $ 5893.28
# =======================================================
# 2019-07-01 | Trade # 47 Opening SHORT Trade
# 2019-07-01 | Trade # 47 Amount = $15893.28
# 2019-07-01 | Trade # 47 Sell Price w/o TCs = $  201.55
# 2019-07-01 | Trade # 47 Sell Price w/ TCs = $  200.54
# 2019-07-01 | Trade # 47 # of Units =    78.00
# 2019-07-01 | Trade # 46 Not enought data to complete trade. Excluding This SHORT Trade From Final Results
# 2019-07-01 | Trade # 46 # of Units =    78.00
# 2019-07-01 | Trade # 46 Cummulative Gain/Loss $ 5893.28
# 2019-07-01 | Trade # 46 STARTING AMOUNT = 10000.00
# 2019-07-01 | Trade # 46 FINAL AMOUNT = 15893.28
# 2019-07-01 | NET RETURN OF STRATEGY =   58.93%
# Number of Indivdual Trades:  46
# Number of Round Trip Trades:  23.0
# Number of Winning Trades: 15
# Win Rate:   65.22%
# IN SAMPLE Model Prediction Accuracy train['d'] vs train['p'] (%) =  49.528301886792455
# OUT OF SAMPLE Model Prediction Accuracy test['d'] vs test['p'] (%) =  57.07547169811321
# ==============================================================================================================
# CPU times: user 6.95 s, sys: 57.8 ms, total: 7.01 s
# Wall time: 8 s

# %%
def Gaussian_OOS():
  out_of_sample_results = pd.DataFrame()
  #Set proportional transaction cost at 0.5%
  ptc = 0.005
  #Sliding window size set to 405 days
  Win = 405
  Gaussian = BacktestingModelsStrategy('AAPL.O', 10000, ptc, 'Gaussian', Win)
  out_of_sample_results = Gaussian.run_strategy(Win)

# %%
# %%time
Gaussian_OOS_Results = Gaussian_OOS()
# Out:
# Win =  405
# ==============================================================================================================
# *** START BACKTESTING ***
# SYM=AAPL.O | Lags=5 | SMA1=35 | SMA2=196 | L1=1.5| L2=8 | EMA1=50 | EMA2=180 | Vol1=90| Vol2=190 | Win=405
# ==============================================================================================================
# Creating GaussianNB Model
# =======================================================
# 2018-09-25 | Trade # 1 Opening SHORT Trade
# 2018-09-25 | Trade # 1 Amount = $10000.00
# 2018-09-25 | Trade # 1 Sell Price w/o TCs = $  222.19
# 2018-09-25 | Trade # 1 Sell Price w/ TCs = $  221.08
# 2018-09-25 | Trade # 1 # of Units =    44.00
# 2019-01-04 | Trade # 2 Closing SHORT Trade
# 2019-01-04 | Trade # 2 Buy Price w/o TCs = $  148.26
# 2019-01-04 | Trade # 2 Buy Price w/ TCs = $  149.00
# 2019-01-04 | Trade # 2 # of Units =    44.00
# 2019-01-04 | Trade # 2 Amount = 13171.42
# 2019-01-04 | Trade # 2 Gain/Loss    32.60%
# 2019-01-04 | Trade # 2 Dollar Gain/Loss $ 3171.42
# 2019-01-04 | Trade # 2 Cummulative Gain/Loss $ 3171.42
# =======================================================
# 2019-01-04 | Trade # 3 Opening LONG Trade
# 2019-01-04 | Trade # 3 Amount = $13171.42
# 2019-01-04 | Trade # 3 Buy Price w/o TCs = $  148.26
# 2019-01-04 | Trade # 3 Buy Price w/ TCs = $  149.00
# 2019-01-04 | Trade # 3 # of Units =    88.00
# 2019-04-24 | Trade # 4 Closing LONG Trade
# 2019-04-24 | Trade # 4 Sell Price w/o TCs = $  207.16
# 2019-04-24 | Trade # 4 Sell Price w/ TCs = $  206.12
# 2019-04-24 | Trade # 4 # of Units =    88.00
# 2019-04-24 | Trade # 4 Amount = 18198.24
# 2019-04-24 | Trade # 4 Gain/Loss    38.34%
# 2019-04-24 | Trade # 4 Dollar Gain/Loss $ 5026.82
# 2019-04-24 | Trade # 4 Cummulative Gain/Loss $ 8198.24
# =======================================================
# 2019-04-24 | Trade # 5 Opening SHORT Trade
# 2019-04-24 | Trade # 5 Amount = $18198.24
# 2019-04-24 | Trade # 5 Sell Price w/o TCs = $  207.16
# 2019-04-24 | Trade # 5 Sell Price w/ TCs = $  206.12
# 2019-04-24 | Trade # 5 # of Units =    87.00
# 2019-07-01 | Trade # 4 Not enought data to complete trade. Excluding This SHORT Trade From Final Results
# 2019-07-01 | Trade # 4 # of Units =    87.00
# 2019-07-01 | Trade # 4 Cummulative Gain/Loss $ 8198.24
# 2019-07-01 | Trade # 4 STARTING AMOUNT = 10000.00
# 2019-07-01 | Trade # 4 FINAL AMOUNT = 18198.24
# 2019-07-01 | NET RETURN OF STRATEGY =   81.98%
# Number of Indivdual Trades:  4
# Number of Round Trip Trades:  2.0
# Number of Winning Trades: 2
# Win Rate:  100.00%
# IN SAMPLE Model Prediction Accuracy train['d'] vs train['p'] (%) =  50.0
# OUT OF SAMPLE Model Prediction Accuracy test['d'] vs test['p'] (%) =  61.458333333333336
# ==============================================================================================================
# CPU times: user 3.92 s, sys: 31.3 ms, total: 3.95 s
# Wall time: 4.68 s

# %%
def LR_OOS():
  out_of_sample_results = pd.DataFrame()
  #Set proportional transaction cost at 0.5%
  ptc = 0.005
  #Sliding window size set to 300 days
  Win = 300
  LR = BacktestingModelsStrategy('AAPL.O', 10000, ptc, 'LR', 300)
  out_of_sample_results = LR.run_strategy(Win)

# %%
# %%time
LR_OOS_Results = LR_OOS()
# Out:
# Win =  300
# ==============================================================================================================
# *** START BACKTESTING ***
# SYM=AAPL.O | Lags=5 | SMA1=35 | SMA2=196 | L1=1.5| L2=8 | EMA1=50 | EMA2=180 | Vol1=90| Vol2=190 | Win=300
# ==============================================================================================================
# Creating LogisticRegression Model
# =======================================================
# 2018-04-26 | Trade # 1 Opening LONG Trade
# 2018-04-26 | Trade # 1 Amount = $10000.00
# 2018-04-26 | Trade # 1 Buy Price w/o TCs = $  164.22
# 2018-04-26 | Trade # 1 Buy Price w/ TCs = $  165.04
# 2018-04-26 | Trade # 1 # of Units =    60.00
# 2018-09-12 | Trade # 2 Closing LONG Trade
# 2018-09-12 | Trade # 2 Sell Price w/o TCs = $  221.07
# 2018-09-12 | Trade # 2 Sell Price w/ TCs = $  219.96
# 2018-09-12 | Trade # 2 # of Units =    60.00
# 2018-09-12 | Trade # 2 Amount = 13295.41
# 2018-09-12 | Trade # 2 Gain/Loss    33.28%
# 2018-09-12 | Trade # 2 Dollar Gain/Loss $ 3295.41
# 2018-09-12 | Trade # 2 Cummulative Gain/Loss $ 3295.41
# =======================================================
# 2018-09-12 | Trade # 3 Opening SHORT Trade
# 2018-09-12 | Trade # 3 Amount = $13295.41
# 2018-09-12 | Trade # 3 Sell Price w/o TCs = $  221.07
# 2018-09-12 | Trade # 3 Sell Price w/ TCs = $  219.96
# 2018-09-12 | Trade # 3 # of Units =    59.00
# 2019-07-01 | Trade # 2 Not enought data to complete trade. Excluding This SHORT Trade From Final Results
# 2019-07-01 | Trade # 2 # of Units =    59.00
# 2019-07-01 | Trade # 2 Cummulative Gain/Loss $ 3295.41
# 2019-07-01 | Trade # 2 STARTING AMOUNT = 10000.00
# 2019-07-01 | Trade # 2 FINAL AMOUNT = 13295.41
# 2019-07-01 | NET RETURN OF STRATEGY =   32.95%
# Number of Indivdual Trades:  2
# Number of Round Trip Trades:  1.0
# Number of Winning Trades: 1
# Win Rate:  100.00%
# IN SAMPLE Model Prediction Accuracy train['d'] vs train['p'] (%) =  43.77104377104377
# OUT OF SAMPLE Model Prediction Accuracy test['d'] vs test['p'] (%) =  50.841750841750844
# ==============================================================================================================
# CPU times: user 38.1 s, sys: 26.3 s, total: 1min 4s
# Wall time: 39.3 s

# %%
def SVC_OOS():
  out_of_sample_results = pd.DataFrame()
  #Set proportional transaction cost at 0.5%
  ptc = 0.005
  #Sliding window size set to 60 days
  Win = 60
  SVC = BacktestingModelsStrategy('AAPL.O', 10000, ptc, 'SVC', Win)
  out_of_sample_results = SVC.run_strategy(Win)

# %%
# %%time
SVC_OOS_Results = SVC_OOS()
# Out:
# Win =  60
# ==============================================================================================================
# *** START BACKTESTING ***
# SYM=AAPL.O | Lags=5 | SMA1=35 | SMA2=196 | L1=1.5| L2=8 | EMA1=50 | EMA2=180 | Vol1=90| Vol2=190 | Win=60
# ==============================================================================================================
# Creating SVC Model
# =======================================================
# 2017-05-12 | Trade # 1 Opening LONG Trade
# 2017-05-12 | Trade # 1 Amount = $10000.00
# 2017-05-12 | Trade # 1 Buy Price w/o TCs = $  156.10
# 2017-05-12 | Trade # 1 Buy Price w/ TCs = $  156.88
# 2017-05-12 | Trade # 1 # of Units =    63.00
# 2017-06-02 | Trade # 2 Closing LONG Trade
# 2017-06-02 | Trade # 2 Sell Price w/o TCs = $  155.45
# 2017-06-02 | Trade # 2 Sell Price w/ TCs = $  154.67
# 2017-06-02 | Trade # 2 # of Units =    63.00
# 2017-06-02 | Trade # 2 Amount =  9860.91
# 2017-06-02 | Trade # 2 Gain/Loss    -1.41%
# 2017-06-02 | Trade # 2 Dollar Gain/Loss $ -139.09
# 2017-06-02 | Trade # 2 Cummulative Gain/Loss $ -139.09
# =======================================================
# 2017-06-02 | Trade # 3 Opening SHORT Trade
# 2017-06-02 | Trade # 3 Amount = $ 9860.91
# 2017-06-02 | Trade # 3 Sell Price w/o TCs = $  155.45
# 2017-06-02 | Trade # 3 Sell Price w/ TCs = $  154.67
# 2017-06-02 | Trade # 3 # of Units =    63.00
# 2017-07-12 | Trade # 4 Closing SHORT Trade
# 2017-07-12 | Trade # 4 Buy Price w/o TCs = $  145.74
# 2017-07-12 | Trade # 4 Buy Price w/ TCs = $  146.47
# 2017-07-12 | Trade # 4 # of Units =    63.00
# 2017-07-12 | Trade # 4 Amount = 10377.77
# 2017-07-12 | Trade # 4 Gain/Loss     5.30%
# 2017-07-12 | Trade # 4 Dollar Gain/Loss $  516.86
# 2017-07-12 | Trade # 4 Cummulative Gain/Loss $  377.77
# =======================================================
# 2017-07-12 | Trade # 5 Opening LONG Trade
# 2017-07-12 | Trade # 5 Amount = $10377.77
# 2017-07-12 | Trade # 5 Buy Price w/o TCs = $  145.74
# 2017-07-12 | Trade # 5 Buy Price w/ TCs = $  146.47
# 2017-07-12 | Trade # 5 # of Units =    70.00
# 2017-07-26 | Trade # 6 Closing LONG Trade
# 2017-07-26 | Trade # 6 Sell Price w/o TCs = $  153.46
# 2017-07-26 | Trade # 6 Sell Price w/ TCs = $  152.69
# 2017-07-26 | Trade # 6 # of Units =    70.00
# 2017-07-26 | Trade # 6 Amount = 10813.45
# 2017-07-26 | Trade # 6 Gain/Loss     4.25%
# 2017-07-26 | Trade # 6 Dollar Gain/Loss $  435.68
# 2017-07-26 | Trade # 6 Cummulative Gain/Loss $  813.45
# =======================================================
# 2017-07-26 | Trade # 7 Opening SHORT Trade
# 2017-07-26 | Trade # 7 Amount = $10813.45
# 2017-07-26 | Trade # 7 Sell Price w/o TCs = $  153.46
# 2017-07-26 | Trade # 7 Sell Price w/ TCs = $  152.69
# 2017-07-26 | Trade # 7 # of Units =    70.00
# 2017-07-27 | Trade # 8 Closing SHORT Trade
# 2017-07-27 | Trade # 8 Buy Price w/o TCs = $  150.56
# 2017-07-27 | Trade # 8 Buy Price w/ TCs = $  151.31
# 2017-07-27 | Trade # 8 # of Units =    70.00
# 2017-07-27 | Trade # 8 Amount = 10910.04
# 2017-07-27 | Trade # 8 Gain/Loss     0.90%
# 2017-07-27 | Trade # 8 Dollar Gain/Loss $   96.59
# 2017-07-27 | Trade # 8 Cummulative Gain/Loss $  910.04
# =======================================================
# 2017-07-27 | Trade # 9 Opening LONG Trade
# 2017-07-27 | Trade # 9 Amount = $10910.04
# 2017-07-27 | Trade # 9 Buy Price w/o TCs = $  150.56
# 2017-07-27 | Trade # 9 Buy Price w/ TCs = $  151.31
# 2017-07-27 | Trade # 9 # of Units =    72.00
# 2017-07-28 | Trade # 10 Closing LONG Trade
# 2017-07-28 | Trade # 10 Sell Price w/o TCs = $  149.50
# 2017-07-28 | Trade # 10 Sell Price w/ TCs = $  148.75
# 2017-07-28 | Trade # 10 # of Units =    72.00
# 2017-07-28 | Trade # 10 Amount = 10725.70
# 2017-07-28 | Trade # 10 Gain/Loss    -1.69%
# 2017-07-28 | Trade # 10 Dollar Gain/Loss $ -184.34
# 2017-07-28 | Trade # 10 Cummulative Gain/Loss $  725.70
# =======================================================
# 2017-07-28 | Trade # 11 Opening SHORT Trade
# 2017-07-28 | Trade # 11 Amount = $10725.70
# 2017-07-28 | Trade # 11 Sell Price w/o TCs = $  149.50
# 2017-07-28 | Trade # 11 Sell Price w/ TCs = $  148.75
# 2017-07-28 | Trade # 11 # of Units =    71.00
# 2017-08-01 | Trade # 12 Closing SHORT Trade
# 2017-08-01 | Trade # 12 Buy Price w/o TCs = $  150.05
# 2017-08-01 | Trade # 12 Buy Price w/ TCs = $  150.80
# 2017-08-01 | Trade # 12 # of Units =    71.00
# 2017-08-01 | Trade # 12 Amount = 10580.31
# 2017-08-01 | Trade # 12 Gain/Loss    -1.38%
# 2017-08-01 | Trade # 12 Dollar Gain/Loss $ -145.39
# 2017-08-01 | Trade # 12 Cummulative Gain/Loss $  580.31
# =======================================================
# 2017-08-01 | Trade # 13 Opening LONG Trade
# 2017-08-01 | Trade # 13 Amount = $10580.31
# 2017-08-01 | Trade # 13 Buy Price w/o TCs = $  150.05
# 2017-08-01 | Trade # 13 Buy Price w/ TCs = $  150.80
# 2017-08-01 | Trade # 13 # of Units =    70.00
# 2017-08-09 | Trade # 14 Closing LONG Trade
# 2017-08-09 | Trade # 14 Sell Price w/o TCs = $  161.06
# 2017-08-09 | Trade # 14 Sell Price w/ TCs = $  160.25
# 2017-08-09 | Trade # 14 # of Units =    70.00
# 2017-08-09 | Trade # 14 Amount = 11242.12
# 2017-08-09 | Trade # 14 Gain/Loss     6.27%
# 2017-08-09 | Trade # 14 Dollar Gain/Loss $  661.81
# 2017-08-09 | Trade # 14 Cummulative Gain/Loss $ 1242.12
# =======================================================
# 2017-08-09 | Trade # 15 Opening SHORT Trade
# 2017-08-09 | Trade # 15 Amount = $11242.12
# 2017-08-09 | Trade # 15 Sell Price w/o TCs = $  161.06
# 2017-08-09 | Trade # 15 Sell Price w/ TCs = $  160.25
# 2017-08-09 | Trade # 15 # of Units =    69.00
# 2017-08-10 | Trade # 16 Closing SHORT Trade
# 2017-08-10 | Trade # 16 Buy Price w/o TCs = $  155.32
# 2017-08-10 | Trade # 16 Buy Price w/ TCs = $  156.10
# 2017-08-10 | Trade # 16 # of Units =    69.00
# 2017-08-10 | Trade # 16 Amount = 11529.03
# 2017-08-10 | Trade # 16 Gain/Loss     2.59%
# 2017-08-10 | Trade # 16 Dollar Gain/Loss $  286.91
# 2017-08-10 | Trade # 16 Cummulative Gain/Loss $ 1529.03
# =======================================================
# 2017-08-10 | Trade # 17 Opening LONG Trade
# 2017-08-10 | Trade # 17 Amount = $11529.03
# 2017-08-10 | Trade # 17 Buy Price w/o TCs = $  155.32
# 2017-08-10 | Trade # 17 Buy Price w/ TCs = $  156.10
# 2017-08-10 | Trade # 17 # of Units =    73.00
# 2017-11-24 | Trade # 18 Closing LONG Trade
# 2017-11-24 | Trade # 18 Sell Price w/o TCs = $  174.97
# 2017-11-24 | Trade # 18 Sell Price w/ TCs = $  174.10
# 2017-11-24 | Trade # 18 # of Units =    73.00
# 2017-11-24 | Trade # 18 Amount = 12842.92
# 2017-11-24 | Trade # 18 Gain/Loss    11.53%
# 2017-11-24 | Trade # 18 Dollar Gain/Loss $ 1313.89
# 2017-11-24 | Trade # 18 Cummulative Gain/Loss $ 2842.92
# =======================================================
# 2017-11-24 | Trade # 19 Opening SHORT Trade
# 2017-11-24 | Trade # 19 Amount = $12842.92
# 2017-11-24 | Trade # 19 Sell Price w/o TCs = $  174.97
# 2017-11-24 | Trade # 19 Sell Price w/ TCs = $  174.10
# 2017-11-24 | Trade # 19 # of Units =    73.00
# 2018-02-12 | Trade # 20 Closing SHORT Trade
# 2018-02-12 | Trade # 20 Buy Price w/o TCs = $  162.71
# 2018-02-12 | Trade # 20 Buy Price w/ TCs = $  163.52
# 2018-02-12 | Trade # 20 # of Units =    73.00
# 2018-02-12 | Trade # 20 Amount = 13614.65
# 2018-02-12 | Trade # 20 Gain/Loss     6.07%
# 2018-02-12 | Trade # 20 Dollar Gain/Loss $  771.73
# 2018-02-12 | Trade # 20 Cummulative Gain/Loss $ 3614.65
# =======================================================
# 2018-02-12 | Trade # 21 Opening LONG Trade
# 2018-02-12 | Trade # 21 Amount = $13614.65
# 2018-02-12 | Trade # 21 Buy Price w/o TCs = $  162.71
# 2018-02-12 | Trade # 21 Buy Price w/ TCs = $  163.52
# 2018-02-12 | Trade # 21 # of Units =    83.00
# 2018-05-23 | Trade # 22 Closing LONG Trade
# 2018-05-23 | Trade # 22 Sell Price w/o TCs = $  188.36
# 2018-05-23 | Trade # 22 Sell Price w/ TCs = $  187.42
# 2018-05-23 | Trade # 22 # of Units =    83.00
# 2018-05-23 | Trade # 22 Amount = 15597.91
# 2018-05-23 | Trade # 22 Gain/Loss    14.61%
# 2018-05-23 | Trade # 22 Dollar Gain/Loss $ 1983.26
# 2018-05-23 | Trade # 22 Cummulative Gain/Loss $ 5597.91
# =======================================================
# 2018-05-23 | Trade # 23 Opening SHORT Trade
# 2018-05-23 | Trade # 23 Amount = $15597.91
# 2018-05-23 | Trade # 23 Sell Price w/o TCs = $  188.36
# 2018-05-23 | Trade # 23 Sell Price w/ TCs = $  187.42
# 2018-05-23 | Trade # 23 # of Units =    82.00
# 2018-11-26 | Trade # 24 Closing SHORT Trade
# 2018-11-26 | Trade # 24 Buy Price w/o TCs = $  174.62
# 2018-11-26 | Trade # 24 Buy Price w/ TCs = $  175.49
# 2018-11-26 | Trade # 24 # of Units =    82.00
# 2018-11-26 | Trade # 24 Amount = 16575.76
# 2018-11-26 | Trade # 24 Gain/Loss     6.36%
# 2018-11-26 | Trade # 24 Dollar Gain/Loss $  977.86
# 2018-11-26 | Trade # 24 Cummulative Gain/Loss $ 6575.76
# =======================================================
# 2018-11-26 | Trade # 25 Opening LONG Trade
# 2018-11-26 | Trade # 25 Amount = $16575.76
# 2018-11-26 | Trade # 25 Buy Price w/o TCs = $  174.62
# 2018-11-26 | Trade # 25 Buy Price w/ TCs = $  175.49
# 2018-11-26 | Trade # 25 # of Units =    94.00
# 2018-12-21 | Trade # 26 Closing LONG Trade
# 2018-12-21 | Trade # 26 Sell Price w/o TCs = $  150.73
# 2018-12-21 | Trade # 26 Sell Price w/ TCs = $  149.98
# 2018-12-21 | Trade # 26 # of Units =    94.00
# 2018-12-21 | Trade # 26 Amount = 14177.19
# 2018-12-21 | Trade # 26 Gain/Loss   -14.54%
# 2018-12-21 | Trade # 26 Dollar Gain/Loss $-2398.57
# 2018-12-21 | Trade # 26 Cummulative Gain/Loss $ 4177.19
# =======================================================
# 2018-12-21 | Trade # 27 Opening SHORT Trade
# 2018-12-21 | Trade # 27 Amount = $14177.19
# 2018-12-21 | Trade # 27 Sell Price w/o TCs = $  150.73
# 2018-12-21 | Trade # 27 Sell Price w/ TCs = $  149.98
# 2018-12-21 | Trade # 27 # of Units =    93.00
# 2018-12-24 | Trade # 28 Closing SHORT Trade
# 2018-12-24 | Trade # 28 Buy Price w/o TCs = $  146.83
# 2018-12-24 | Trade # 28 Buy Price w/ TCs = $  147.56
# 2018-12-24 | Trade # 28 # of Units =    93.00
# 2018-12-24 | Trade # 28 Amount = 14401.52
# 2018-12-24 | Trade # 28 Gain/Loss     1.61%
# 2018-12-24 | Trade # 28 Dollar Gain/Loss $  224.33
# 2018-12-24 | Trade # 28 Cummulative Gain/Loss $ 4401.52
# =======================================================
# 2018-12-24 | Trade # 29 Opening LONG Trade
# 2018-12-24 | Trade # 29 Amount = $14401.52
# 2018-12-24 | Trade # 29 Buy Price w/o TCs = $  146.83
# 2018-12-24 | Trade # 29 Buy Price w/ TCs = $  147.56
# 2018-12-24 | Trade # 29 # of Units =    97.00
# 2018-12-28 | Trade # 30 Closing LONG Trade
# 2018-12-28 | Trade # 30 Sell Price w/o TCs = $  156.23
# 2018-12-28 | Trade # 30 Sell Price w/ TCs = $  155.45
# 2018-12-28 | Trade # 30 # of Units =    97.00
# 2018-12-28 | Trade # 30 Amount = 15166.34
# 2018-12-28 | Trade # 30 Gain/Loss     5.34%
# 2018-12-28 | Trade # 30 Dollar Gain/Loss $  764.82
# 2018-12-28 | Trade # 30 Cummulative Gain/Loss $ 5166.34
# =======================================================
# 2018-12-28 | Trade # 31 Opening SHORT Trade
# 2018-12-28 | Trade # 31 Amount = $15166.34
# 2018-12-28 | Trade # 31 Sell Price w/o TCs = $  156.23
# 2018-12-28 | Trade # 31 Sell Price w/ TCs = $  155.45
# 2018-12-28 | Trade # 31 # of Units =    96.00
# 2019-01-25 | Trade # 32 Closing SHORT Trade
# 2019-01-25 | Trade # 32 Buy Price w/o TCs = $  157.76
# 2019-01-25 | Trade # 32 Buy Price w/ TCs = $  158.55
# 2019-01-25 | Trade # 32 # of Units =    96.00
# 2019-01-25 | Trade # 32 Amount = 14868.74
# 2019-01-25 | Trade # 32 Gain/Loss    -1.99%
# 2019-01-25 | Trade # 32 Dollar Gain/Loss $ -297.60
# 2019-01-25 | Trade # 32 Cummulative Gain/Loss $ 4868.74
# =======================================================
# 2019-01-25 | Trade # 33 Opening LONG Trade
# 2019-01-25 | Trade # 33 Amount = $14868.74
# 2019-01-25 | Trade # 33 Buy Price w/o TCs = $  157.76
# 2019-01-25 | Trade # 33 Buy Price w/ TCs = $  158.55
# 2019-01-25 | Trade # 33 # of Units =    93.00
# 2019-02-06 | Trade # 34 Closing LONG Trade
# 2019-02-06 | Trade # 34 Sell Price w/o TCs = $  174.24
# 2019-02-06 | Trade # 34 Sell Price w/ TCs = $  173.37
# 2019-02-06 | Trade # 34 # of Units =    93.00
# 2019-02-06 | Trade # 34 Amount = 16247.00
# 2019-02-06 | Trade # 34 Gain/Loss     9.35%
# 2019-02-06 | Trade # 34 Dollar Gain/Loss $ 1378.26
# 2019-02-06 | Trade # 34 Cummulative Gain/Loss $ 6247.00
# =======================================================
# 2019-02-06 | Trade # 35 Opening SHORT Trade
# 2019-02-06 | Trade # 35 Amount = $16247.00
# 2019-02-06 | Trade # 35 Sell Price w/o TCs = $  174.24
# 2019-02-06 | Trade # 35 Sell Price w/ TCs = $  173.37
# 2019-02-06 | Trade # 35 # of Units =    92.00
# 2019-02-07 | Trade # 36 Closing SHORT Trade
# 2019-02-07 | Trade # 36 Buy Price w/o TCs = $  170.94
# 2019-02-07 | Trade # 36 Buy Price w/ TCs = $  171.79
# 2019-02-07 | Trade # 36 # of Units =    92.00
# 2019-02-07 | Trade # 36 Amount = 16391.82
# 2019-02-07 | Trade # 36 Gain/Loss     0.91%
# 2019-02-07 | Trade # 36 Dollar Gain/Loss $  144.82
# 2019-02-07 | Trade # 36 Cummulative Gain/Loss $ 6391.82
# =======================================================
# 2019-02-07 | Trade # 37 Opening LONG Trade
# 2019-02-07 | Trade # 37 Amount = $16391.82
# 2019-02-07 | Trade # 37 Buy Price w/o TCs = $  170.94
# 2019-02-07 | Trade # 37 Buy Price w/ TCs = $  171.79
# 2019-02-07 | Trade # 37 # of Units =    95.00
# 2019-02-12 | Trade # 38 Closing LONG Trade
# 2019-02-12 | Trade # 38 Sell Price w/o TCs = $  170.89
# 2019-02-12 | Trade # 38 Sell Price w/ TCs = $  170.04
# 2019-02-12 | Trade # 38 # of Units =    95.00
# 2019-02-12 | Trade # 38 Amount = 16224.70
# 2019-02-12 | Trade # 38 Gain/Loss    -1.02%
# 2019-02-12 | Trade # 38 Dollar Gain/Loss $ -167.12
# 2019-02-12 | Trade # 38 Cummulative Gain/Loss $ 6224.70
# =======================================================
# 2019-02-12 | Trade # 39 Opening SHORT Trade
# 2019-02-12 | Trade # 39 Amount = $16224.70
# 2019-02-12 | Trade # 39 Sell Price w/o TCs = $  170.89
# 2019-02-12 | Trade # 39 Sell Price w/ TCs = $  170.04
# 2019-02-12 | Trade # 39 # of Units =    94.00
# 2019-02-13 | Trade # 40 Closing SHORT Trade
# 2019-02-13 | Trade # 40 Buy Price w/o TCs = $  170.18
# 2019-02-13 | Trade # 40 Buy Price w/ TCs = $  171.03
# 2019-02-13 | Trade # 40 # of Units =    94.00
# 2019-02-13 | Trade # 40 Amount = 16131.14
# 2019-02-13 | Trade # 40 Gain/Loss    -0.59%
# 2019-02-13 | Trade # 40 Dollar Gain/Loss $  -93.56
# 2019-02-13 | Trade # 40 Cummulative Gain/Loss $ 6131.14
# =======================================================
# 2019-02-13 | Trade # 41 Opening LONG Trade
# 2019-02-13 | Trade # 41 Amount = $16131.14
# 2019-02-13 | Trade # 41 Buy Price w/o TCs = $  170.18
# 2019-02-13 | Trade # 41 Buy Price w/ TCs = $  171.03
# 2019-02-13 | Trade # 41 # of Units =    94.00
# 2019-07-01 | Trade # 40 Not enough data to complete trade. Excluding This LONG Trade From Final Results
# 2019-07-01 | Trade # 40 # of Units =    94.00
# 2019-07-01 | Trade # 40 Cummulative Gain/Loss $ 6131.14
# 2019-07-01 | Trade # 40 STARTING AMOUNT = 10000.00
# 2019-07-01 | Trade # 40 FINAL AMOUNT = 16131.14
# 2019-07-01 | NET RETURN OF STRATEGY =   61.31%
# Number of Indivdual Trades:  40
# Number of Round Trip Trades:  20.0
# Number of Winning Trades: 13
# Win Rate:   65.00%
# IN SAMPLE Model Prediction Accuracy train['d'] vs train['p'] (%) =  50.09310986964618
# OUT OF SAMPLE Model Prediction Accuracy test['d'] vs test['p'] (%) =  51.21042830540037
# ==============================================================================================================
# CPU times: user 13.4 s, sys: 58.6 ms, total: 13.4 s
# Wall time: 14.3 s

# %%
def MLPC_OOS():
  out_of_sample_results = pd.DataFrame()
  #Set proportional transaction cost at 0.5%
  ptc = 0.005
  #Sliding window size set to 360 days
  Win = 360
  MLPC = BacktestingModelsStrategy('AAPL.O', 10000, ptc, 'MLPC', Win)
  out_of_sample_results = MLPC.run_strategy(Win)

# %%
# %%time
MLPC_OOS_Results = MLPC_OOS()
# Out:
# Win =  360
# ==============================================================================================================
# *** START BACKTESTING ***
# SYM=AAPL.O | Lags=5 | SMA1=35 | SMA2=196 | L1=1.5| L2=8 | EMA1=50 | EMA2=180 | Vol1=90| Vol2=190 | Win=360
# ==============================================================================================================
# Creating MLPClassifier Model
# =======================================================
# 2018-07-23 | Trade # 1 Opening LONG Trade
# 2018-07-23 | Trade # 1 Amount = $10000.00
# 2018-07-23 | Trade # 1 Buy Price w/o TCs = $  191.61
# 2018-07-23 | Trade # 1 Buy Price w/ TCs = $  192.57
# 2018-07-23 | Trade # 1 # of Units =    51.00
# 2019-04-24 | Trade # 2 Closing LONG Trade
# 2019-04-24 | Trade # 2 Sell Price w/o TCs = $  207.16
# 2019-04-24 | Trade # 2 Sell Price w/ TCs = $  206.12
# 2019-04-24 | Trade # 2 # of Units =    51.00
# 2019-04-24 | Trade # 2 Amount = 10691.36
# 2019-04-24 | Trade # 2 Gain/Loss     7.04%
# 2019-04-24 | Trade # 2 Dollar Gain/Loss $  691.36
# 2019-04-24 | Trade # 2 Cummulative Gain/Loss $  691.36
# =======================================================
# 2019-04-24 | Trade # 3 Opening SHORT Trade
# 2019-04-24 | Trade # 3 Amount = $10691.36
# 2019-04-24 | Trade # 3 Sell Price w/o TCs = $  207.16
# 2019-04-24 | Trade # 3 Sell Price w/ TCs = $  206.12
# 2019-04-24 | Trade # 3 # of Units =    51.00
# 2019-04-26 | Trade # 4 Closing SHORT Trade
# 2019-04-26 | Trade # 4 Buy Price w/o TCs = $  204.30
# 2019-04-26 | Trade # 4 Buy Price w/ TCs = $  205.32
# 2019-04-26 | Trade # 4 # of Units =    51.00
# 2019-04-26 | Trade # 4 Amount = 10732.30
# 2019-04-26 | Trade # 4 Gain/Loss     0.39%
# 2019-04-26 | Trade # 4 Dollar Gain/Loss $   40.94
# 2019-04-26 | Trade # 4 Cummulative Gain/Loss $  732.30
# =======================================================
# 2019-04-26 | Trade # 5 Opening LONG Trade
# 2019-04-26 | Trade # 5 Amount = $10732.30
# 2019-04-26 | Trade # 5 Buy Price w/o TCs = $  204.30
# 2019-04-26 | Trade # 5 Buy Price w/ TCs = $  205.32
# 2019-04-26 | Trade # 5 # of Units =    52.00
# 2019-04-29 | Trade # 6 Closing LONG Trade
# 2019-04-29 | Trade # 6 Sell Price w/o TCs = $  204.61
# 2019-04-29 | Trade # 6 Sell Price w/ TCs = $  203.59
# 2019-04-29 | Trade # 6 # of Units =    52.00
# 2019-04-29 | Trade # 6 Amount = 10642.10
# 2019-04-29 | Trade # 6 Gain/Loss    -0.84%
# 2019-04-29 | Trade # 6 Dollar Gain/Loss $  -90.20
# 2019-04-29 | Trade # 6 Cummulative Gain/Loss $  642.10
# =======================================================
# 2019-04-29 | Trade # 7 Opening SHORT Trade
# 2019-04-29 | Trade # 7 Amount = $10642.10
# 2019-04-29 | Trade # 7 Sell Price w/o TCs = $  204.61
# 2019-04-29 | Trade # 7 Sell Price w/ TCs = $  203.59
# 2019-04-29 | Trade # 7 # of Units =    51.00
# 2019-05-09 | Trade # 8 Closing SHORT Trade
# 2019-05-09 | Trade # 8 Buy Price w/o TCs = $  200.72
# 2019-05-09 | Trade # 8 Buy Price w/ TCs = $  201.72
# 2019-05-09 | Trade # 8 # of Units =    51.00
# 2019-05-09 | Trade # 8 Amount = 10737.14
# 2019-05-09 | Trade # 8 Gain/Loss     0.92%
# 2019-05-09 | Trade # 8 Dollar Gain/Loss $   95.03
# 2019-05-09 | Trade # 8 Cummulative Gain/Loss $  737.14
# =======================================================
# 2019-05-09 | Trade # 9 Opening LONG Trade
# 2019-05-09 | Trade # 9 Amount = $10737.14
# 2019-05-09 | Trade # 9 Buy Price w/o TCs = $  200.72
# 2019-05-09 | Trade # 9 Buy Price w/ TCs = $  201.72
# 2019-05-09 | Trade # 9 # of Units =    53.00
# 2019-05-10 | Trade # 10 Closing LONG Trade
# 2019-05-10 | Trade # 10 Sell Price w/o TCs = $  197.18
# 2019-05-10 | Trade # 10 Sell Price w/ TCs = $  196.19
# 2019-05-10 | Trade # 10 # of Units =    53.00
# 2019-05-10 | Trade # 10 Amount = 10444.07
# 2019-05-10 | Trade # 10 Gain/Loss    -2.74%
# 2019-05-10 | Trade # 10 Dollar Gain/Loss $ -293.06
# 2019-05-10 | Trade # 10 Cummulative Gain/Loss $  444.07
# =======================================================
# 2019-05-10 | Trade # 11 Opening SHORT Trade
# 2019-05-10 | Trade # 11 Amount = $10444.07
# 2019-05-10 | Trade # 11 Sell Price w/o TCs = $  197.18
# 2019-05-10 | Trade # 11 Sell Price w/ TCs = $  196.19
# 2019-05-10 | Trade # 11 # of Units =    52.00
# 2019-05-23 | Trade # 12 Closing SHORT Trade
# 2019-05-23 | Trade # 12 Buy Price w/o TCs = $  179.66
# 2019-05-23 | Trade # 12 Buy Price w/ TCs = $  180.56
# 2019-05-23 | Trade # 12 # of Units =    52.00
# 2019-05-23 | Trade # 12 Amount = 11257.13
# 2019-05-23 | Trade # 12 Gain/Loss     7.97%
# 2019-05-23 | Trade # 12 Dollar Gain/Loss $  813.06
# 2019-05-23 | Trade # 12 Cummulative Gain/Loss $ 1257.13
# =======================================================
# 2019-05-23 | Trade # 13 Opening LONG Trade
# 2019-05-23 | Trade # 13 Amount = $11257.13
# 2019-05-23 | Trade # 13 Buy Price w/o TCs = $  179.66
# 2019-05-23 | Trade # 13 Buy Price w/ TCs = $  180.56
# 2019-05-23 | Trade # 13 # of Units =    62.00
# 2019-06-24 | Trade # 14 Closing LONG Trade
# 2019-06-24 | Trade # 14 Sell Price w/o TCs = $  198.58
# 2019-06-24 | Trade # 14 Sell Price w/ TCs = $  197.59
# 2019-06-24 | Trade # 14 # of Units =    62.00
# 2019-06-24 | Trade # 14 Amount = 12312.92
# 2019-06-24 | Trade # 14 Gain/Loss     9.43%
# 2019-06-24 | Trade # 14 Dollar Gain/Loss $ 1055.79
# 2019-06-24 | Trade # 14 Cummulative Gain/Loss $ 2312.92
# =======================================================
# 2019-06-24 | Trade # 15 Opening SHORT Trade
# 2019-06-24 | Trade # 15 Amount = $12312.92
# 2019-06-24 | Trade # 15 Sell Price w/o TCs = $  198.58
# 2019-06-24 | Trade # 15 Sell Price w/ TCs = $  197.59
# 2019-06-24 | Trade # 15 # of Units =    61.00
# 2019-06-25 | Trade # 16 Closing SHORT Trade
# 2019-06-25 | Trade # 16 Buy Price w/o TCs = $  195.57
# 2019-06-25 | Trade # 16 Buy Price w/ TCs = $  196.55
# 2019-06-25 | Trade # 16 # of Units =    61.00
# 2019-06-25 | Trade # 16 Amount = 12376.31
# 2019-06-25 | Trade # 16 Gain/Loss     0.53%
# 2019-06-25 | Trade # 16 Dollar Gain/Loss $   63.39
# 2019-06-25 | Trade # 16 Cummulative Gain/Loss $ 2376.31
# =======================================================
# 2019-06-25 | Trade # 17 Opening LONG Trade
# 2019-06-25 | Trade # 17 Amount = $12376.31
# 2019-06-25 | Trade # 17 Buy Price w/o TCs = $  195.57
# 2019-06-25 | Trade # 17 Buy Price w/ TCs = $  196.55
# 2019-06-25 | Trade # 17 # of Units =    62.00
# 2019-07-01 | Trade # 16 Not enough data to complete trade. Excluding This LONG Trade From Final Results
# 2019-07-01 | Trade # 16 # of Units =    62.00
# 2019-07-01 | Trade # 16 Cummulative Gain/Loss $ 2376.31
# 2019-07-01 | Trade # 16 STARTING AMOUNT = 10000.00
# 2019-07-01 | Trade # 16 FINAL AMOUNT = 12376.31
# 2019-07-01 | NET RETURN OF STRATEGY =   23.76%
# Number of Indivdual Trades:  16
# Number of Round Trip Trades:  8.0
# Number of Winning Trades: 6
# Win Rate:   75.00%
# IN SAMPLE Model Prediction Accuracy train['d'] vs train['p'] (%) =  45.9915611814346
# OUT OF SAMPLE Model Prediction Accuracy test['d'] vs test['p'] (%) =  57.80590717299579
# ==============================================================================================================
# CPU times: user 8min 49s, sys: 5min 30s, total: 14min 20s
# Wall time: 8min 32s
